# %% [markdown]
# ## NAB Corpus

# %% [markdown]
# ##### The NAB corpus of 58 timeseries data files is designed to provide data for research in streaming anomaly detection. It is comprised of both real-world and artifical timeseries data containing labeled anomalous periods of behavior. Data are ordered, timestamped, single-valued metrics. All data files contain anomalies, unless otherwise noted.
# https://www.kaggle.com/datasets/boltzmannbrain/nab
#
# ##### The majority of the data is real-world from a variety of sources such as AWS server metrics, Twitter volume, advertisement clicking metrics, traffic data, and more. All data is included in the repository, with more details in the data readme
#
# ##### realKnownCause:
#
# This is data for which we know the anomaly causes; no hand labeling.
#
# ambient_temperature_system_failure.csv: The ambient temperature in an office
# setting.

# %%
# !pip install pyod
# Out:
# Requirement already satisfied: pyod in /usr/local/lib/python3.10/dist-packages (1.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from pyod) (1.3.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pyod) (3.7.1)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.10/dist-packages (from pyod) (1.23.5)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.10/dist-packages (from pyod) (0.58.1)
# Requirement already satisfied: scipy>=1.5.1 in /usr/local/lib/python3.10/dist-packages (from pyod) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from pyod) (1.2.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from pyod) (1.16.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51->pyod) (0.41.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.0->pyod) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyod) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyod) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyod) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyod) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyod) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyod) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyod) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyod) (2.8.2)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import median_abs_deviation
from pyod.models.mad import MAD
from sklearn.model_selection import train_test_split
import warnings
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings("ignore")
from sklearn.ensemble import IsolationForest
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
raw_df = pd.read_csv("/content/ambient_temperature_system_failure.csv")
raw_df.head()
# Out:
#              timestamp      value
# 0  2013-07-04 00:00:00  69.880835
# 1  2013-07-04 01:00:00  71.220227
# 2  2013-07-04 02:00:00  70.877805
# 3  2013-07-04 03:00:00  68.959400
# 4  2013-07-04 04:00:00  69.283551

# %%
df = raw_df.copy()
df
# Out:
#                 timestamp      value
# 0     2013-07-04 00:00:00  69.880835
# 1     2013-07-04 01:00:00  71.220227
# 2     2013-07-04 02:00:00  70.877805
# 3     2013-07-04 03:00:00  68.959400
# 4     2013-07-04 04:00:00  69.283551
# ...                   ...        ...
# 7262  2014-05-28 11:00:00  72.370206
# 7263  2014-05-28 12:00:00  72.172956
# 7264  2014-05-28 13:00:00  72.046565
# 7265  2014-05-28 14:00:00  71.825226
# 7266  2014-05-28 15:00:00  72.584089
#
# [7267 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  7267 non-null   object
#  1   value      7267 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 113.7+ KB

# %%
print(df.nunique())
print(df.isnull().sum())
# Out:
# timestamp    7267
# value        7267
# dtype: int64
# timestamp    0
# value        0
# dtype: int64

# %% [markdown]
# ##### EDA and Data Analysis

# %%
# change the timestamp attribute data type
df['timestamp'] = pd.to_datetime(df['timestamp'])
print(df.dtypes)
# Out:
# timestamp    datetime64[ns]
# value               float64
# dtype: object

# %%
shows_added = df.groupby('timestamp')[['value']].count()
shows_added
# Out:
#                      value
# timestamp
# 2013-07-04 00:00:00      1
# 2013-07-04 01:00:00      1
# 2013-07-04 02:00:00      1
# 2013-07-04 03:00:00      1
# 2013-07-04 04:00:00      1
# ...                    ...
# 2014-05-28 11:00:00      1
# 2014-05-28 12:00:00      1
# 2014-05-28 13:00:00      1
# 2014-05-28 14:00:00      1
# 2014-05-28 15:00:00      1
#
# [7267 rows x 1 columns]

# %%
df = df.set_index('timestamp')
df.head()
# Out:
#                          value
# timestamp
# 2013-07-04 00:00:00  69.880835
# 2013-07-04 01:00:00  71.220227
# 2013-07-04 02:00:00  70.877805
# 2013-07-04 03:00:00  68.959400
# 2013-07-04 04:00:00  69.283551

# %%
#The day of the week with Monday=0, Sunday=6.
df['day_of_week'] = df.index.day_name()
df
# Out:
#                          value day_of_week
# timestamp
# 2013-07-04 00:00:00  69.880835    Thursday
# 2013-07-04 01:00:00  71.220227    Thursday
# 2013-07-04 02:00:00  70.877805    Thursday
# 2013-07-04 03:00:00  68.959400    Thursday
# 2013-07-04 04:00:00  69.283551    Thursday
# ...                        ...         ...
# 2014-05-28 11:00:00  72.370206   Wednesday
# 2014-05-28 12:00:00  72.172956   Wednesday
# 2014-05-28 13:00:00  72.046565   Wednesday
# 2014-05-28 14:00:00  71.825226   Wednesday
# 2014-05-28 15:00:00  72.584089   Wednesday
#
# [7267 rows x 2 columns]

# %%
shows_added = df.groupby('day_of_week')[['value']].mean()
shows_added
# Out:
#                  value
# day_of_week
# Friday       72.247876
# Monday       70.557101
# Saturday     70.683072
# Sunday       69.137005
# Thursday     72.256499
# Tuesday      71.590582
# Wednesday    72.044910

# %%
df['is_month_end'] = df.index.is_month_end
df
# Out:
#                          value day_of_week  is_month_end
# timestamp
# 2013-07-04 00:00:00  69.880835    Thursday         False
# 2013-07-04 01:00:00  71.220227    Thursday         False
# 2013-07-04 02:00:00  70.877805    Thursday         False
# 2013-07-04 03:00:00  68.959400    Thursday         False
# 2013-07-04 04:00:00  69.283551    Thursday         False
# ...                        ...         ...           ...
# 2014-05-28 11:00:00  72.370206   Wednesday         False
# 2014-05-28 12:00:00  72.172956   Wednesday         False
# 2014-05-28 13:00:00  72.046565   Wednesday         False
# 2014-05-28 14:00:00  71.825226   Wednesday         False
# 2014-05-28 15:00:00  72.584089   Wednesday         False
#
# [7267 rows x 3 columns]

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('is_month_end').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['day_of_week'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='value', y='day_of_week', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df['quarter_hear'] = df.index.quarter
df.quarter_hear.astype(int)
# Out:
# timestamp
# 2013-07-04 00:00:00    3
# 2013-07-04 01:00:00    3
# 2013-07-04 02:00:00    3
# 2013-07-04 03:00:00    3
# 2013-07-04 04:00:00    3
#                       ..
# 2014-05-28 11:00:00    2
# 2014-05-28 12:00:00    2
# 2014-05-28 13:00:00    2
# 2014-05-28 14:00:00    2
# 2014-05-28 15:00:00    2
# Name: quarter_hear, Length: 7267, dtype: int64

# %%
value_of_quarter_year = df.groupby('quarter_hear')['value'].mean()
value_of_quarter_year
# Out:
# quarter_hear
# 1    71.233359
# 2    66.311612
# 3    70.056963
# 4    75.072179
# Name: value, dtype: float64

# %%
value_of_quarter_year.plot()
# Out:
# <Axes: xlabel='quarter_hear'>

# %% [markdown]
# The temperature  is usually decreasing in the the second quarter if the year

# %%
weekly_value = df['value'].resample('1M').mean()   # For each week.mean()
weekly_value.plot()
# Out:
# <Axes: xlabel='timestamp'>

# %% [markdown]
# an obvious decrease in the time between Dec 2013 till Mar 2014

# %%
weekly_value
# Out:
# timestamp
# 2013-07-31    70.289853
# 2013-08-31    69.289786
# 2013-09-30    70.863810
# 2013-10-31    73.972191
# 2013-11-30    74.770478
# 2013-12-31    76.342900
# 2014-01-31    74.243393
# 2014-02-28    71.643594
# 2014-03-31    67.635159
# 2014-04-30    66.144435
# 2014-05-31    66.449333
# Freq: M, Name: value, dtype: float64

# %%
df.head()
# Out:
#                          value day_of_week  is_month_end  quarter_hear
# timestamp
# 2013-07-04 00:00:00  69.880835    Thursday         False             3
# 2013-07-04 01:00:00  71.220227    Thursday         False             3
# 2013-07-04 02:00:00  70.877805    Thursday         False             3
# 2013-07-04 03:00:00  68.959400    Thursday         False             3
# 2013-07-04 04:00:00  69.283551    Thursday         False             3

# %%
df['value'].hist()
# Out:
# <Axes: >

# %% [markdown]
# The dataset tends to be Normally distributed

# %%
df['value'].plot(color = 'red', figsize = (15, 5))
plt.title('The value of the temperature from 2013 to 2014')
plt.show()

# %%
# Select from the date 2013-07-04 00:00:00 to 2013-12-31 11:59:00, so that we can make a close look to the change of the value
df['2013-07-04 00:00:00' : '2013-12-31 11:59:00'].plot(color = 'red', figsize = (15, 5))
plt.title('The value of the temperature over 2013')
plt.show()

# %%
# Select from the date 2014-01-01 00:00:00 to 2014-05-28 15:00:00, so that we can make a close look to the change of the value
df['2014-01-01 00:00:00' : '2014-05-28 15:00:00'].plot(color = 'red', figsize = (15, 5))
plt.title('The value of the temperature over 2014')
plt.show()

# %%
import plotly.graph_objects as go
fig = go.Figure([go.Scatter(x = df.index, y = df['value'])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f84485e2-03dc-4532-be7f-bdb5be88fa6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f84485e2-03dc-4532-be7f-bdb5be88fa6f")) {                    Plotly.newPlot(                        "f84485e2-03dc-4532-be7f-bdb5be88fa6f",                        [{"x":["2013-07-04T00:00:00","2013-07-04T01:00:00","2013-07-04T02:00:00","2013-07-04T03:00:00","2013-07-04T04:00:00","2013-07-04T05:00:00","2013-07-04T06:00:00","2013-07-04T07:00:00","2013-07-04T08:00:00","2013-07-04T09:00:00","2013-07-04T10:00:00","2013-07-04T11:00:00","2013-07-04T12:00:00","2013-07-04T13:00:00","2013-07-04T14:00:00","2013-07-04T15:00:00","2013-07-04T16:00:00","2013-07-04T17:00:00","2013-07-04T18:00:00","2013-07-04T19:00:00","2013-07-04T20:00:00","2013-07-04T21:00:00","2013-07-04T22:00:00","2013-07-04T23:00:00","2013-07-05T00:00:00","2013-07-05T01:00:00","2013-07-05T02:00:00","2013-07-05T03:00:00","2013-07-05T04:00:00","2013-07-05T05:00:00","2013-07-05T06:00:00","2013-07-05T07:00:00","2013-07-05T08:00:00","2013-07-05T09:00:00","2013-07-05T10:00:00","2013-07-05T11:00:00","2013-07-05T12:00:00","2013-07-05T13:00:00","2013-07-05T14:00:00","2013-07-05T15:00:00","2013-07-05T16:00:00","2013-07-05T17:00:00","2013-07-05T18:00:00","2013-07-05T19:00:00","2013-07-05T20:00:00","2013-07-05T21:00:00","2013-07-05T22:00:00","2013-07-05T23:00:00","2013-07-06T00:00:00","2013-07-06T01:00:00","2013-07-06T02:00:00","2013-07-06T03:00:00","2013-07-06T04:00:00","2013-07-06T05:00:00","2013-07-06T06:00:00","2013-07-06T07:00:00","2013-07-06T08:00:00","2013-07-06T09:00:00","2013-07-06T10:00:00","2013-07-06T11:00:00","2013-07-06T12:00:00","2013-07-06T13:00:00","2013-07-06T14:00:00","2013-07-06T15:00:00","2013-07-06T16:00:00","2013-07-06T17:00:00","2013-07-06T18:00:00","2013-07-06T19:00:00","2013-07-06T20:00:00","2013-07-06T21:00:00","2013-07-06T22:00:00","2013-07-06T23:00:00","2013-07-07T00:00:00","2013-07-07T01:00:00","2013-07-07T02:00:00","2013-07-07T03:00:00","2013-07-07T04:00:00","2013-07-07T05:00:00","2013-07-07T06:00:00","2013-07-07T07:00:00","2013-07-07T08:00:00","2013-07-07T09:00:00","2013-07-07T10:00:00","2013-07-07T11:00:00","2013-07-07T12:00:00","2013-07-07T13:00:00","2013-07-07T14:00:00","2013-07-07T15:00:00","2013-07-07T16:00:00","2013-07-07T17:00:00","2013-07-07T18:00:00","2013-07-07T19:00:00","2013-07-07T20:00:00","2013-07-07T21:00:00","2013-07-07T22:00:00","2013-07-07T23:00:00","2013-07-08T00:00:00","2013-07-08T01:00:00","2013-07-08T02:00:00","2013-07-08T03:00:00","2013-07-08T04:00:00","2013-07-08T05:00:00","2013-07-08T06:00:00","2013-07-08T07:00:00","2013-07-08T08:00:00","2013-07-08T09:00:00","2013-07-08T10:00:00","2013-07-08T11:00:00","2013-07-08T12:00:00","2013-07-08T13:00:00","2013-07-08T14:00:00","2013-07-08T15:00:00","2013-07-08T16:00:00","2013-07-08T17:00:00","2013-07-08T18:00:00","2013-07-08T19:00:00","2013-07-08T20:00:00","2013-07-08T21:00:00","2013-07-08T22:00:00","2013-07-08T23:00:00","2013-07-09T00:00:00","2013-07-09T01:00:00","2013-07-09T02:00:00","2013-07-09T03:00:00","2013-07-09T04:00:00","2013-07-09T05:00:00","2013-07-09T06:00:00","2013-07-09T07:00:00","2013-07-09T08:00:00","2013-07-09T09:00:00","2013-07-09T10:00:00","2013-07-09T11:00:00","2013-07-09T12:00:00","2013-07-09T13:00:00","2013-07-09T14:00:00","2013-07-09T15:00:00","2013-07-09T16:00:00","2013-07-09T17:00:00","2013-07-09T18:00:00","2013-07-09T19:00:00","2013-07-09T20:00:00","2013-07-09T21:00:00","2013-07-09T22:00:00","2013-07-09T23:00:00","2013-07-10T00:00:00","2013-07-10T01:00:00","2013-07-10T02:00:00","2013-07-10T03:00:00","2013-07-10T04:00:00","2013-07-10T05:00:00","2013-07-10T06:00:00","2013-07-10T07:00:00","2013-07-10T08:00:00","2013-07-10T09:00:00","2013-07-10T10:00:00","2013-07-10T11:00:00 ...

# %% [markdown]
# Here we can notice that the overall temperature  started decreasing starting from almost (Jan 12, 2014, 21:00) -The last peak- the temperature  was (80.9) and decreased overtime

# %%
print(df.index.freq)
# Out:
# None

# %%
#applying STL decompose to divide the time series into smaller components
plt.rc('figure',figsize=(12,8))
plt.rc('font',size=15)
result = seasonal_decompose(df, model="additive", period=12)
fig = result.plot()

# %% [markdown]
# Identifying trends: the overall temperature decreasing over time

# %% [markdown]
# Detect anomalies: residuals reveal spikes or outliers

# %% [markdown]
# #### Checking Stationarity

# %%
#split the time series into two contiguous sequences. We can then calculate the mean and variance of each group of numbers and compare the values
X = df.values
split = round(len(X) / 2)
X1, X2 = X[0:split], X[split:]
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=72.344377, mean2=70.140185
# variance1=11.136285, variance2=22.513756

# %% [markdown]
# they have almost the same mean but different variance values

# %% [markdown]
# #####Augmented Dickey-Fuller test

# %%
# apply augmented dickey fuller test to make sure that if the data is stationary
from statsmodels.tsa.stattools import adfuller
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
 print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -5.517563
# p-value: 0.000002
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %% [markdown]
# H0 (Null Hypohesis): the data is non stationary
#
# H1 (Alternative Hypothesis): the data is stationary
#
# p-value > 0.05: Fail to reject the null hypothesis (H0), the data has a unit root and is non-stationary.
#
# p-value <= 0.05: Reject the null hypothesis (H0), the data does not have a unit root and is stationary

# %% [markdown]
# As part of the output, we get a look-up table to help determine the ADF statistic. We can see that our statistic value of -5 is less than the value of -3.431 at 2%.
#
# This suggests that we can reject the null hypothesis with a significance level of less than 2% (i.e. a low probability that the result is a statistical fluke).
#
# Rejecting the null hypothesis means that the process has no unit root, and in turn that the time series is stationary or does not have time-dependent structure.
